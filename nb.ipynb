# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.patches import Patch

# %%
senna_df = pd.read_csv('data-csv/qualifying-results_ayrton-senna.csv')
prost_df = pd.read_csv('data-csv/qualifying-results_alain-prost.csv')
mansell_df = pd.read_csv('data-csv/qualifying-results_nigel-mansell.csv')
piquet_df = pd.read_csv('data-csv/qualifying-results_nelson-piquet.csv')
berger_df = pd.read_csv('data-csv/qualifying-results_gerhard-berger.csv')
cecotto_df = pd.read_csv('data-csv/qualifying-results_johnny-cecotto.csv')
johansson_df = pd.read_csv('data-csv/qualifying-results_stefan-johansson.csv')
dumfries_df = pd.read_csv('data-csv/qualifying-results_johnny-dumfries.csv')
angelis_df = pd.read_csv('data-csv/qualifying-results_elio-de-angelis.csv')
nakajima_df = pd.read_csv('data-csv/qualifying-results_satoru-nakajima.csv')

# %%
years_1988_1994 = [1988, 1989, 1990, 1991, 1992, 1993, 1994]
years_until_1991 = [1988, 1989, 1990, 1991]
years_wo_1994 = [1988, 1989, 1990, 1991, 1992, 1993]

senna_data_1988_1994 = senna_df[senna_df['year'].isin(years_1988_1994)]
prost_data_1988_1991 = prost_df[prost_df['year'].isin(years_until_1991)]
prost_data_1993 = prost_df[prost_df['year'] == 1993]
mansell_data_1988_1992 = mansell_df[mansell_df['year'].isin(years_wo_1994)]
piquet_data_1988_1991 = piquet_df[piquet_df['year'].isin(years_until_1991)]
berger_data_1988_1993 = berger_df[berger_df['year'].isin(years_wo_1994)]
berger_data_1994 = berger_df[berger_df['year'] == 1994].head(3)
berger_data_1991_1994 = pd.concat([berger_data_1988_1993, berger_data_1994], axis=0)

# In order to avoid SettingWithCopyWarning
senna_data_1988_1994 = senna_data_1988_1994.copy()
prost_data_1988_1991 = prost_data_1988_1991.copy()
prost_data_1993 = prost_data_1993.copy()
mansell_data_1988_1992 = mansell_data_1988_1992.copy()
piquet_data_1988_1991 = piquet_data_1988_1991.copy()
berger_data_1991_1994 = berger_data_1991_1994.copy()

senna_data_1988_1994['year_race'] = senna_data_1988_1994['race'] + " (" + senna_data_1988_1994['year'].astype(str) + ')'
prost_data_1988_1991['year_race'] = prost_data_1988_1991['race'] + " (" + prost_data_1988_1991['year'].astype(str) + ')'
prost_data_1993['year_race'] = prost_data_1993['race'] + " (" + prost_data_1993['year'].astype(str) + ')'
mansell_data_1988_1992['year_race'] = mansell_data_1988_1992['race'] + " (" + mansell_data_1988_1992['year'].astype(str) + ')'
piquet_data_1988_1991['year_race'] = piquet_data_1988_1991['race'] + " (" + piquet_data_1988_1991['year'].astype(str) + ')'
berger_data_1991_1994['year_race'] = berger_data_1991_1994['race'] + " (" + berger_data_1991_1994['year'].astype(str) + ')'

# %%
plt.figure(figsize=(28,8))

plt.plot(senna_data_1988_1994['year_race'], senna_data_1988_1994['position'], marker='o', linestyle='-', color='#e91c0d', markersize=2, label='Ayrton Senna')
plt.plot(prost_data_1988_1991['year_race'], prost_data_1988_1991['position'], marker='o', linestyle='-', color='#0066CC', markersize=2, label='Alain Prost')
plt.plot(prost_data_1993['year_race'], prost_data_1993['position'], marker='o', linestyle='-', color='#0066CC', markersize=2, label='')
plt.plot(mansell_data_1988_1992['year_race'], mansell_data_1988_1992['position'], marker='o', linestyle='-', color='#ffb700', markersize=2, label='Nigel Mansell')
plt.plot(piquet_data_1988_1991['year_race'], piquet_data_1988_1991['position'], marker='o', linestyle='-', color='#38812F', markersize=2, label='Nelson Piquet')
plt.plot(berger_data_1991_1994['year_race'], berger_data_1991_1994['position'], marker='o', linestyle='-', color='#5a1b1b', markersize=2, label='Michael Schumacher')

plt.title('Ayrton Senna vs Other Drivers - Qualifying Results (1988-1994)', fontsize=14)
plt.xlabel('Race (Year)', fontsize=12)
plt.ylabel('Qualifying Position', fontsize=12)
plt.xticks(rotation=90, fontsize=10)
plt.yticks([1, 5, 10, 15, 20, 25], fontsize=10)
plt.gca().invert_yaxis()

start_index = senna_data_1988_1994[senna_data_1988_1994['year'] == 1992].index[0] - senna_data_1988_1994[senna_data_1988_1994['year'] == 1988].index[0]
plt.axvspan(start_index, len(senna_data_1988_1994['year_race'])-1, facecolor='#8BC1F7', alpha=0.5)

plt.grid(False)

legend_elements = [
    Patch(facecolor='#8BC1F7', edgecolor='#8BC1F7', label='Williams Racing Dominance'),
]

plt.legend(handles=plt.gca().get_legend_handles_labels()[0] + legend_elements)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Toleman

# %%
senna_data_1984 = senna_df[senna_df['year'] == 1984]
cecotto_data_1984 = cecotto_df[cecotto_df['year'] == 1984]
johansson_data_1984 = johansson_df[johansson_df['year'] == 1984]

# In order to avoid SettingWithCopyWarning
senna_data_1984 = senna_data_1984.copy()
cecotto_data_1984 = cecotto_data_1984.copy()
johansson_data_1984 = johansson_data_1984.copy()

senna_data_1984['year_race'] = senna_data_1984['race'] + " (" + senna_data_1984['year'].astype(str) + ')'
cecotto_data_1984['year_race'] = cecotto_data_1984['race'] + " (" + cecotto_data_1984['year'].astype(str) + ')'
johansson_data_1984['year_race'] = johansson_data_1984['race'] + " (" + johansson_data_1984['year'].astype(str) + ')'

# %%
plt.figure(figsize=(10,4))

plt.plot(senna_data_1984['year_race'], senna_data_1984['position'], marker='o', linestyle='-', color='#e91c0d', markersize=2, label='Ayrton Senna')
plt.plot(cecotto_data_1984['year_race'], cecotto_data_1984['position'], marker='o', linestyle='-', color='#0066CC', markersize=2, label='Johnny Cecotto')
plt.plot(johansson_data_1984['year_race'], johansson_data_1984['position'], marker='o', linestyle='-', color='#ffb700', markersize=2, label='Stefan Johansson')

plt.title('', fontsize=14)
plt.xlabel('Race (Year)', fontsize=12)
plt.ylabel('Qualifying Position', fontsize=12)
plt.xticks(rotation=90, fontsize=10)
plt.yticks([1, 5, 10, 15, 20, 25], fontsize=10)
plt.gca().invert_yaxis()

plt.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Lotus

# %%
lotus_years = [1985, 1986, 1987]

senna_data_1985_1987 = senna_df[senna_df['year'].isin(lotus_years)]
angelis_data_1985 = angelis_df[angelis_df['year'] == 1985]
dumfries_data_1986 = dumfries_df[dumfries_df['year'] == 1986]
nakajima_data_1987 = nakajima_df[nakajima_df['year'] == 1987]


# In order to avoid SettingWithCopyWarning
senna_data_1985_1987 = senna_data_1985_1987.copy()
angelis_data_1985 = angelis_data_1985.copy()
dumfries_data_1986 = dumfries_data_1986.copy()
nakajima_data_1987 = nakajima_data_1987.copy()

senna_data_1985_1987['year_race'] = senna_data_1985_1987['race'] + " (" + senna_data_1985_1987['year'].astype(str) + ')'
angelis_data_1985['year_race'] = angelis_data_1985['race'] + " (" + angelis_data_1985['year'].astype(str) + ')'
dumfries_data_1986['year_race'] = dumfries_data_1986['race'] + " (" + dumfries_data_1986['year'].astype(str) + ')'
nakajima_data_1987['year_race'] = nakajima_data_1987['race'] + " (" + nakajima_data_1987['year'].astype(str) + ')'

# %%
plt.figure(figsize=(16,6))

plt.plot(senna_data_1985_1987['year_race'], senna_data_1985_1987['position'], marker='o', linestyle='-', color='#e91c0d', markersize=2, label='Ayrton Senna')
plt.plot(angelis_data_1985['year_race'], angelis_data_1985['position'], marker='o', linestyle='-', color='#0066CC', markersize=2, label='Elio de Angelis')
plt.plot(dumfries_data_1986['year_race'], dumfries_data_1986['position'], marker='o', linestyle='-', color='#ffb700', markersize=2, label='Johnny Dumfries')
plt.plot(nakajima_data_1987['year_race'], nakajima_data_1987['position'], marker='o', linestyle='-', color='#38812F', markersize=2, label='Satoru Nakagima')

plt.title('', fontsize=14)
plt.xlabel('Race (Year)', fontsize=12)
plt.ylabel('Qualifying Position', fontsize=12)
plt.xticks(rotation=90, fontsize=10)
plt.yticks([1, 5, 10, 15, 20, 25], fontsize=10)
plt.gca().invert_yaxis()

plt.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# fazer um tratamento de dados melhor para os graficos (sem gambiarra de apagar o csv)
#
#
# corridas com chuva
# -porcentagem de vitorias
# -grafico com diferença de tempos com outros pilotos
# -monaco com a toleman
# -volta do seculo
#
# porcentagem de podios e pole positions por total de corridas
#
# Championship Win Probability Over Time
#
# line chart - diferença de qualifying para a corrida antes da mclaren (mostrar que sempre melhorava sua posição)
